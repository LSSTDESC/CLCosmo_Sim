# %%
import sys
import os
os.environ['CLMM_MODELING_BACKEND'] = 'ccl'
import clmm
import clmm.dataops
from clmm.dataops import compute_tangential_and_cross_components, make_radial_profile, make_bins
from clmm.galaxycluster import GalaxyCluster
import clmm.utils as u
from clmm import Cosmology
from clmm.support import mock_data as mock
cosmo = Cosmology(H0 = 71.0, Omega_dm0 = 0.265 - 0.0448, Omega_b0 = 0.0448, Omega_k0 = 0.0)
import numpy as np
import pyccl as ccl
import numpy as np
import sys
import matplotlib.pyplot as plt
from astropy.cosmology import FlatLambdaCDM
from scipy.integrate import quad,simps, dblquad
# %load_ext autoreload

# %autoreload 2
from astropy.io import fits as fits
from cluster_toolkit import miscentering
from cluster_toolkit import deltasigma
sys.path.append('../modeling')
import CL_COUNT_modeling_completeness as comp
import CL_COUNT_modeling_purity as pur
import CL_COUNT_modeling_halo_mass_function as hmf
import CL_COUNT_modeling_richness_mass_relation as rm_relation
import CL_MASS_cluster_mass as cl_mass
import CL_COUNT_cluster_abundance as cl_count
import CL_COUNT_class_likelihood as likelihood
import CL_LENSING_cluster_lensing as cl_lensing
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Miscentering in data

# %%
name = '../data/matched_pairs_Mfofcut.fits'
dat = fits.open(name)
dat_open= dat[1].data

# %%
dat_open
# Out:
# FITS_rec([('10', 0.5135129 , 52.52043643, -25.71799612, 190.70665  , 3.7469666,  1312945563, 0.51072353, 0.79138356, '1162500021323', '1162500021323', '1162500021323,922700021315,205900021323,417800021323,665600021315,1361100021315,711400021315,80500021323', '80500021323,922700021315,205900021323,417800021323,665600021315,1361100021315,711400021315,1162500021323', 0.44967262, 0.30094044, '1162500021323', 0.44967262, '1162500021323', 0.51072352, 52.52043643, -25.71799612, 5.46154289e+14, 3.26491145e+14, 1.15600879e+12, '10', '10', '10', '10', 0.44967262, 0.30094044, '10', 0.30094044),
#           ('18', 0.5712697 , 56.92037653, -27.20434071, 179.12813  , 3.6934361,  2000524808, 0.5740297 , 0.99996513, '549500032315', '549500032315', '549500032315', '549500032315', 0.94216489, 0.35064935, '549500032315', 0.94216489, '549500032315', 0.57402969, 56.92037653, -27.20434071, 1.00953537e+15, 6.45749231e+14, 1.58908916e+11, '18', '18', '18', '18', 0.94216489, 0.35064935, '18', 0.35064935),
# ...

# %%
theta = ((dat_open['cat1_ra'] - dat_open['cat2_ra'])**2 + (dat_open['cat1_dec'] - dat_open['cat2_dec'])**2)**.5*(np.pi/180)
Da = cosmo.eval_da_z1z2(0, dat_open['cat2_z'])
R = theta*Da

# %%
bins=np.linspace(0.00000001, 2, 100)
plt.hist(R, bins=bins, density=True)
plt.plot(bins,cl_lensing.miscentering_distribution(bins, .14))
plt.show()

# %%
import cluster_toolkit as ct

# %%
logm = 14
cluster_m = 10**logm
cluster_z = 0.5
moo = clmm.Modeling(massdef = 'critical', delta_mdef = 200, halo_profile_model = 'nfw')
mock_cosmo = Cosmology(H0=70.0, Omega_dm0=0.27-0.045, Omega_b0=0.045, Omega_k0=0.0)
cosmo_ccl = ccl.Cosmology(Omega_c=0.27-0.045, Omega_b=0.045, h=0.7, A_s=2.1e-9, n_s=0.96, Neff=0, Omega_g=0)
deff = ccl.halos.massdef.MassDef(200, 'critical')
conc = ccl.halos.concentration.ConcentrationDiemer15(mass_def=deff)
concentration = conc._concentration(cosmo_ccl, 10**logm, 1/(1 + cluster_z))
moo.set_cosmo(mock_cosmo)
moo.set_mass(cluster_m) 
moo.set_concentration(concentration)

# %%
print('concentration = ' + str(concentration))
# Out:
# concentration = 4.689413285693464

# %% [markdown]
# ### Compute Miscentering

# %%
R_real = np.logspace(np.log10(.1), np.log10(30), 50)
R_Sigma = np.logspace(np.log10(0.0001), np.log10(32), 500)

# %%
Sigma_nfw_clmm = moo.eval_surface_density(R_Sigma, cluster_z) #Msun/Mpc^2 real

# %%
Rmis = 0.05
ds_mis_rayleigh =  mis.predict_sigma_excess_miscentering(Sigma_nfw_clmm, R_real, R_Sigma, Rmis, cluster_z, "rayleigh", moo)
ds_mis_gamma =  mis.predict_sigma_excess_miscentering(Sigma_nfw_clmm, R_real, R_Sigma, Rmis, cluster_z, "gamma", moo)
# Out:
# DS - S
# DS - S

# %%
ds_mis = ds_mis_gamma

# %% [markdown]
# ### Computing Power spectrum for 2h term

# %%
kk = np.logspace(-5,5 ,100000)

# %%
R = np.logspace(np.log10(.05), np.log10(30), 50)

# %%
ds_unbaised = moo.eval_excess_surface_density_2h(R, cluster_z)
bais_200c = 3

# %%
bais = bais_200c

# %%
ds_mis[1].shape
# Out:
# (500,)

# %%
from cluster_toolkit import boostfactors
import numpy as np
#R = R/0.71 #Mpc/h comoving
B0 = 0.1 #Typical value
Rs = 0.5/0.71 #Mpc/h comoving; typical value
alpha = -1.0 #arbitrary
B = boostfactors.boost_powerlaw_at_R(0.71*R, B0, 0.71*Rs, alpha)

# %%
dL = cosmo.eval_da(cluster_z)
plt.figure(figsize = (10, 3))
#1h cen
plt.loglog(R,moo.eval_excess_surface_density(R,cluster_z), ls='-' , c = 'C0',label = r'$\Delta\Sigma_{nfw}^{\rm cen}$')
#1h cen * f
#plt.loglog(R,0.8*moo.eval_excess_surface_density(R,cluster_z), ls='--' , c = 'b',label = r'$f_{\rm cen}\Delta\Sigma_{nfw}^{\rm cen}$')
#1h offcen
plt.loglog(R_real,ds_mis[0], ls=(0.,(6,10)), c = 'C0', label = r'$\Delta\Sigma_{nfw}^{\rm mis}$')
#2h
plt.loglog(R,bais*moo.eval_excess_surface_density_2h(R,cluster_z), ls = '-', c = 'C1', label = r'$\Delta\Sigma_{2h}$')
#plt.plot(R, ds_unbaised*bais + 1*moo.eval_excess_surface_density(R, cluster_z),':',linewidth=5,label = r'$\Delta\Sigma_{tot} =\Delta\Sigma_{NFW} + \Delta\Sigma_{2h}$')
#ds_tot
f_mis = 0.2
ds_tot = (1-f_mis)*np.interp(R, R_real, ds_mis[0]) + f_mis*moo.eval_excess_surface_density(R,cluster_z) + bais*moo.eval_excess_surface_density_2h(R,cluster_z)
#plt.plot(R, ds_tot,'--C2',linewidth=2,label = r'$f_{\rm cen}\Delta\Sigma_{nfw}^{\rm cen} + (1- f_{\rm cen})\Delta\Sigma_{nfw}^{\rm mis} + \Delta\Sigma_{2h}$')
#
plt.plot(R, ds_tot/B,'C3',linewidth=2,label = r'$(1-f_{\rm cl})\Delta\Sigma_{\rm tot}$',)
plt.xlabel(r'$R [Mpc]$', fontsize = 20)
plt.ylabel(r'$\Delta\Sigma$ ' +'$[$' + r'${\rm M}$' + r'$_\odot\;$'+ r'${\rm Mpc}$'+r'$^{-2}$'r'$]$', fontsize = 20)
plt.xlim(.1,30)
plt.legend(fontsize = 17, frameon = False, loc = 'upper right')
plt.tick_params(axis='both', which = 'major', labelsize= 17)
#plt.savefig('excess_surface_density.png', dpi = 300)
