# %%
# %load_ext autoreload

# %autoreload 2
import numpy as np
import corner, sys
import getdist
from getdist import plots, MCSamples
# %matplotlib inline
import matplotlib.pyplot as plt
sys.path.append('../../modules/')
import numpy as np
#plt.switch_backend("Qt5Agg")

# %%
names = ['1', '2', '3', '4', '5', '6']
labels = [r'\ln \lambda_0', r'\mu_z', r'\mu_m', r'\sigma_{\ln \lambda, 0}', r'\sigma_z', r'\sigma_m']
settings={'mult_bias_correction_order':0,'smooth_scale_2D':4, 'smooth_scale_1D':4, 'boundary_correction_order':0}

# %%
n_cut=19000
name='1-halo=nfw+c-M=Duffy08_rmin=1.0-rmax=3.5_photoz=Truez_hmf=Despali16'
which = 'WLxN'
t = np.load(f'../chains/{which}/MCMC_fit_m-r_{which}_{name}.pkl', allow_pickle = True)
WLxRmax35 = MCSamples(samples=t['flat_chains'][n_cut:],names = names, 
                    labels = labels, 
                     settings=settings, 
                     label='Rmax = 3.5')
name='1-halo=nfw+c-M=Duffy08_rmin=1.0-rmax=4_photoz=Truez_hmf=Despali16'
t = np.load(f'../chains/{which}/MCMC_fit_m-r_{which}_{name}.pkl', allow_pickle = True)
WLxRmax4 = MCSamples(samples=t['flat_chains'][n_cut:],names = names, 
                    labels = labels, 
                     settings=settings, 
                     label='Rmax = 4')
name='1-halo=nfw+c-M=Duffy08_rmin=1.0-rmax=4.5_photoz=Truez_hmf=Despali16'
t = np.load(f'../chains/{which}/MCMC_fit_m-r_{which}_{name}.pkl', allow_pickle = True)
WLxRmax45 = MCSamples(samples=t['flat_chains'][n_cut:],names = names, 
                    labels = labels, 
                     settings=settings, 
                     label='Rmax = 4.5')
name='1-halo=nfw+c-M=Duffy08_rmin=1.0-rmax=5_photoz=Truez_hmf=Despali16'
t = np.load(f'../chains/{which}/MCMC_fit_m-r_{which}_{name}.pkl', allow_pickle = True)
WLxRmax5 = MCSamples(samples=t['flat_chains'][n_cut:],names = names, 
                    labels = labels, 
                     settings=settings, 
                     label='Rmax = 5')
name='1-halo=nfw+c-M=Duffy08_rmin=1.0-rmax=5.5_photoz=Truez_hmf=Despali16'
t = np.load(f'../chains/{which}/MCMC_fit_m-r_{which}_{name}.pkl', allow_pickle = True)
WLxRmax55 = MCSamples(samples=t['flat_chains'][n_cut:],names = names, 
                    labels = labels, 
                     settings=settings, 
                     label='Rmax = 5.5')

name='1-halo=nfw+c-M=Duffy08_rmin=1.0-rmax=8_photoz=Truez_hmf=Despali16'
t = np.load(f'../chains/{which}/MCMC_fit_m-r_{which}_{name}.pkl', allow_pickle = True)
WLxRmax8 = MCSamples(samples=t['flat_chains'][n_cut:],names = names, 
                    labels = labels, 
                     settings=settings, 
                     label='Rmax = 8')

name='1-halo=nfw+c-M=Duffy08_rmin=1.0-rmax=10_photoz=Truez_hmf=Despali16'
t = np.load(f'../chains/{which}/MCMC_fit_m-r_{which}_{name}.pkl', allow_pickle = True)
WLxRmax10 = MCSamples(samples=t['flat_chains'][n_cut:],names = names, 
                    labels = labels, 
                     settings=settings, 
                     label='Rmax = 10')
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %%
params_fid=[3.345953364933381,
 0.06378674560099672,
 2.2274595352385975,
 0.5634900828247924,
 -0.04529427946062734,
 0.09764409931399064]
markers={f'{i+1}':params_fid[i] for i in range(len(params_fid))}

# %%
markers={f'{i+1}':params_fid[i] for i in range(len(params_fid))}

# %%
markers
# Out:
# {'1': 3.345953364933381,
#  '2': 0.06378674560099672,
#  '3': 2.2274595352385975,
#  '4': 0.5634900828247924,
#  '5': -0.04529427946062734,
#  '6': 0.09764409931399064}

# %%
g = plots.get_subplot_plotter(subplot_size=2.)
g.settings.lab_fontsize = 20
g.settings.legend_fontsize = 15
g.settings.axes_fontsize = 13
marker_args = {'lw':0.75, 'markersize':0.75, 'ls':'--','color':'b'}
range_ = {'1':[2.5,4], '2':[-2,2], '3':[1,4], '4':[0.1,1.2],'5':[-1.5,1.5], '6':[-0.5,0.5], }
g.triangle_plot(
                [WLxRmax35,WLxRmax55, WLxRmax10], 
                filled=[True, False, False, False, False], 
                contour_colors = ['indianred','royalblue','k'], 
                contour_ls=['-','-','--', '-', '-'],
                contour_lws=[1,1.5,1.5,1,2],
                legend_fontsize = 10,
                #param_limits=range_,
                params=['1','2','3',],markers=markers,
                fine_bins = 1,  marker_args = marker_args, )
#plt.savefig(f'../fig/mcmc_scaling_relation_{name}_alone.png', dpi = 300)
