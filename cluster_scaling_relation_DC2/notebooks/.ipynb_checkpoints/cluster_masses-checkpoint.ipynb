# %%
# %load_ext autoreload

# %autoreload 2
import matplotlib.pyplot as plt
import pickle
from astropy.io import fits as fits
from astropy.coordinates import SkyCoord, match_coordinates_3d, match_coordinates_sky
import sys
import emcee
import numpy as np
from astropy.cosmology import FlatLambdaCDM
import astropy.units as u
from astropy.table import Table, QTable, hstack, vstack
from astropy import units as u
import corner
from astropy.coordinates import SkyCoord, match_coordinates_3d
cosmo_astropy = FlatLambdaCDM(H0=71.0, Om0=0.265, Ob0 = 0.0448)
import iminuit
from iminuit import Minuit
sys.path.append('/pbs/throng/lsst/users/cpayerne/CLMassDC2/modules/')
import analysis_Mass_Richness_relation as analysis
import analysis_WL_mean_mass as analysisM
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
name = '/pbs/throng/lsst/users/cpayerne/CLMassDC2/data/matched_pairs_Mfofcut.fits'
dat = fits.open(name)
#mask = (match['redshift_1'] > .2)*(match['redshift_1'] < 1)
#mask = mask*(match['obs_2'] > 20)*(match['obs_1'] > 3e13)*(match['obs_2'] < 120)
#match = match[mask]
dat_open= dat[1].data
richness = dat_open['cat1_richness']
redshift = dat_open['cat2_z']
M200c = dat_open['cat2_M200c']

# %%
case = analysisM.analysis_WL

# %%
case['halo_model'][1]['ID']
# Out:
# 'halomodel2'

# %%
import glob
file = glob.glob('/pbs/throng/lsst/users/cpayerne/CLMassDC2/notebooks/plots/WL_mean_masses/*')

# %%
file
# Out:
# ['/pbs/throng/lsst/users/cpayerne/CLMassDC2/notebooks/plots/WL_mean_masses/cM_nfw_Prada12.pkl',
#  '/pbs/throng/lsst/users/cpayerne/CLMassDC2/notebooks/plots/WL_mean_masses/PZ_nfw_Diemer15_BPZ.pkl',
#  '/pbs/throng/lsst/users/cpayerne/CLMassDC2/notebooks/plots/WL_mean_masses/PZ_nfw_Diemer15_flex.pkl',
#  '/pbs/throng/lsst/users/cpayerne/CLMassDC2/notebooks/plots/WL_mean_masses/2h_nfw_two_halo_term_freec.pkl',
#  '/pbs/throng/lsst/users/cpayerne/CLMassDC2/notebooks/plots/WL_mean_masses/2h_nfw_two_halo_term_Diemer15.pkl',
#  '/pbs/throng/lsst/users/cpayerne/CLMassDC2/notebooks/plots/WL_mean_masses/cM_nfw_Duffy08.pkl',
#  '/pbs/throng/lsst/users/cpayerne/CLMassDC2/notebooks/plots/WL_mean_masses/cM_nfw_Diemer15.pkl',
#  '/pbs/throng/lsst/users/cpayerne/CLMassDC2/notebooks/plots/WL_mean_masses/halomodel_hernquist_freec.pkl',
#  '/pbs/throng/lsst/users/cpayerne/CLMassDC2/notebooks/plots/WL_mean_masses/halomodel_nfw_freec.pkl',
# ...

# %%
id_analysis = []
masses = []
for i, f in enumerate(file):
    id_analysis.append(np.load(f, allow_pickle=True)['analysis'])
    masses.append(np.load(f, allow_pickle=True)['masses'])

# %%
# id_analysis

# %%
# m = analysis.Obs_bin[0]
# name_analysis = ['photoz', 'two_halo_term', 'cM', 'halo_model']
# color = ['C0', 'C1', 'C2', 'C3']
# marker = ['o','x','d','s']
# for k, m in enumerate(analysis.Obs_bin):
#     for j in range(len(id_analysis)):
#             if np.isin(id_analysis[j],['halomodel1'])==False:
#                 a=1
#             else:
#                 mask = (masses[j]['obs_mean'] > m[0])*(masses[j]['obs_mean'] < m[1])
#                 mask = mask*(masses[j]['z_mean'] > 0.2)*(masses[j]['z_mean'] < .3)
#                 plt.errorbar(masses[j]['log10M200c_WL'][mask],masses[j]['c_w'][mask],yerr = masses[j]['c_w_err'][mask], fmt = ' ', color = 'k', marker = '^', capsize=3,)
#             if np.isin(id_analysis[j],['cM4','cM5'])==False:
#                 a=1
#             else:
#                 mask = (masses[j]['obs_mean'] > m[0])*(masses[j]['obs_mean'] < m[1])
#                 mask = mask*(masses[j]['z_mean'] > 0.2)*(masses[j]['z_mean'] < .3)
#                 plt.errorbar(masses[j]['log10M200c_WL'][mask],masses[j]['c_w'][mask], fmt = ' ', color = 'k', marker = '+', capsize=5,)

# %%
z_bin = analysis.Z_bin[3]
print(z_bin)
plt.title(f'$z \in [{z_bin[0]},{z_bin[1]}]$')
for k, m in enumerate(analysis.Obs_bin):
    name_analysis = ['photoz', 'two_halo_term', 'cM', 'halo_model']
    color = ['C0', 'C1', 'C2', 'C3']
    marker = ['o','x','d','s']
    for i, analysis_ in enumerate(name_analysis):
        list_of_possibles_indexes = [c['ID'] for c in case[analysis_]]
        name_plot = [c['name_analysis'] for c in case[analysis_]]
        for j in range(len(file)):
            id_res = id_analysis[j]
            maskid = [l == id_res for l in list_of_possibles_indexes]

            if len(np.array(maskid)[np.array(maskid)==True]) == 0: continue
            else: 
                name_plot_ = np.array(name_plot)[maskid][0]
                mask = (masses[j]['obs_mean'] > m[0])*(masses[j]['obs_mean'] < m[1])
                mask = mask*(masses[j]['z_mean'] > z_bin[0])*(masses[j]['z_mean'] < z_bin[1])
                mask_true = (richness > m[0])*(richness < m[1])
                mask_true = mask_true*(redshift >  z_bin[0])*(redshift <  z_bin[1])
                #plt.vlines(np.log10(np.mean(M200c[mask_true])), -1, 11, color='k', lw=.3, zorder=0)
                
                plt.errorbar(masses[j]['log10M200c_WL'][mask],name_plot_, xerr = masses[j]['err_log10M200c_WL'][mask], color = color[i], marker = marker[k], capsize=3,)
   # plt.errorbar(np.log10(np.mean(M200c[mask_true])), 'redMaPPer-cosmoDC2 match', xerr = (np.log(10)*np.mean(M200c[mask_true]))**(-1) * np.std(M200c[mask_true])/np.sqrt(len(M200c[mask_true])), 
      #           color='k',capsize=3, lw=.3, zorder=0, marker = marker[k])
plt.xticks(rotation = 0)
plt.xlabel(r'$\log_{10}M_{\rm 200c}\ [M_\odot]$', fontsize=15)
plt.ylim(-.5, 10.5)
plt.xlim(14, 14.8)
plt.savefig('lensing_masses2.png', bbox_inches='tight', dpi=300)
# Out:
# [0.5, 0.6]

# %%
file_plot = file[3]
mass_file = masses[3]

# %%
file_plot
# Out:
# '/pbs/throng/lsst/users/cpayerne/CLMassDC2/notebooks/plots/WL_mean_masses/2h_nfw_two_halo_term_freec.pkl'

# %%
chains = np.load('/pbs/throng/lsst/users/cpayerne/CLMassDC2/notebooks/plots/WL_mass_richness_relation/2h_nfw_two_halo_term_freec.pkl', allow_pickle=True)['chains']

# %%
plt.plot(chains[:,0])

# %%
params = np.mean(chains[60000:], axis = 0)

# %%
params
# Out:
# array([14.10924448, -0.51391619,  0.78804562])

# %%
import CL_Mass_richness_relation as modeling
z0 = analysis.z0
richness0 = analysis.richness0
modeling = modeling.WL_Mass_Richness()
modeling.set_pivot_values( z0, richness0)

# %%
richness = np.linspace(0, 300, 100)
print(f)
color = ['C' + str(i) for i in range(len(analysis.Z_bin))]
#f = mass_file_einasto_freec
#f = mass_file_hernquist_freec
fig, ax = plt.subplots(1,2,figsize=(10,5), sharex=True, sharey=True)
for k, z_bin in enumerate(analysis.Z_bin):
        f = Table(mass_file)
        mask = (f['z_mean'] > z_bin[0])*(f['z_mean'] < z_bin[1])
        f_cut = f[mask]
        richness = f_cut['obs_mean']
        richness_err = f_cut['obs_rms']
        logm200w = f_cut['log10M200c_WL']
        logm200w_err = f_cut['err_log10M200c_WL']
        
        #logm200w = f_cut['logm200_w']
        #logm200w_err = f_cut['logm200_w_err']
        if np.mean(z_bin) < 0.6: g=0
        else: g=1
        ax[g].plot([],[], '-',label = f'{z_bin[0]:.1f}'+ r'$< z < $'+ f'{z_bin[1]:.1f}', color = color[k])
        ax[g].errorbar(richness,logm200w,logm200w_err, richness_err, fmt = ' ' , color = color[k], marker = 'o', markersize=3)
        ax[g].plot(richness, modeling.lnM(f_cut['obs_mean'], np.mean(z_bin), params)/np.log(10), color = color[k])
        ax[g].legend(fontsize=14, frameon=False, loc = 'upper left')
        ax[g].set_xscale('log')
        ax[g].set_xlim(10, 200)
        ax[g].set_ylabel(r'$\log_{10}M_{\rm 200c}\ [M_\odot]$', fontsize=20)
        ax[g].set_xlabel(r'$\lambda$', fontsize=20)
        ax[g].tick_params(axis='both', which = 'both', labelsize= 13)
#plt.savefig('lesing_masses_single', bbox_inches='tight', dpi=300)
# Out:
#      mask     ...
# ------------- ...
# False .. True ...
# False .. True ...
# False .. True ...
# False .. True ...
# False .. True ...
# False .. True ...
# False .. True ...
# False .. True ...
# False .. True ...
# False .. True ...
#           ... ...
# False .. True ...
# False .. True ...
# False .. True ...
# False .. True ...
# False .. True ...
# False .. True ...
# False .. True ...
# False .. True ...
# False .. True ...
# False .. True ...
# False .. True ...
# Length = 28 rows
