# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.load('ind_profile_redmapper_0_5.pkl', allow_pickle=True)

# %%
r = np.mean(data['radius_true'], axis=0)
ds = np.mean(data['DSt_true'], axis=0)
plt.errorbar(r, ds, np.std(data['DSt_true'], axis=0), fmt = ' ', marker = 'o')
plt.loglog()
# Out:
# []
