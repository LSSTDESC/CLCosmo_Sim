# %%
import numpy as np
import matplotlib.pyplot as plt
import glob

# %%
a = np.load('../data/ind_profile_redmapper_per_cluster_index/ind_profile_redmapper_0_2.pkl', allow_pickle=True)

# %%
plt.loglog(a[1]['radius_true'], a[1]['W_l_true'])
plt.loglog(a[0]['radius_true'], a[0]['W_l_true'])

# %%
from scipy.stats import binned_statistic

# %%
x = np.random.randn(100)

# %%
r = np.linspace(0, 1, 1000)
w = np.exp(-0.2*r)
bin_means, bin_edges, binnumber_sum_wls = binned_statistic(r, w, statistic='sum', bins=np.linspace(0, 1, 5))

# %%
plt.plot(bin_means,
# Out:
# (array([243.87123593, 231.96588521, 220.64173209, 209.87040355]),)
