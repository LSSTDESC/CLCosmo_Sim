# %%
# %load_ext autoreload

# %autoreload 2
from astropy.io import fits as fits
import matplotlib.pyplot as plt
import pickle
import sys
import emcee
import numpy as np
from astropy.cosmology import FlatLambdaCDM
import astropy.units as u
from astropy.table import Table, QTable, hstack, vstack
from astropy import units as u
import corner
cosmo_astropy = FlatLambdaCDM(H0=71.0, Om0=0.265, Ob0 = 0.0448)
import iminuit
from iminuit import Minuit
cosmo_astropy.critical_density(0.4).to(u.Msun / u.Mpc**3).value


sys.path.append('/pbs/throng/lsst/users/cpayerne/CLMassDC2/modules/')
import CL_Mass_richness_relation as mass_richness
import analysis_Mass_Richness_relation as analysis
import multiprocessing
import clmm
import clmm.dataops
from clmm.dataops import compute_tangential_and_cross_components, make_radial_profile, make_bins
from clmm.galaxycluster import GalaxyCluster
import clmm.utils as u
import astropy.units as un
from clmm import Cosmology
from clmm.support import mock_data as mock
import pyccl as ccl

cosmo = Cosmology(H0 = 71.0, Omega_dm0 = 0.265 - 0.0448, Omega_b0 = 0.0448, Omega_k0 = 0.0)
cosmo_astropy = FlatLambdaCDM(H0=71.0, Om0=0.265, Ob0 = 0.0448)
cosmo_clmm = Cosmology(H0 = 71.0, Omega_dm0 = 0.265 - 0.0448, Omega_b0 = 0.0448, Omega_k0 = 0.0)
cosmo_ccl  = ccl.Cosmology(Omega_c=0.265-0.0448, Omega_b=0.0448, h=0.71, A_s=2.1e-9, n_s=0.96, Neff=0, Omega_g=0)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
name = '/pbs/throng/lsst/users/cpayerne/CLMassDC2/data/matched_pairs_Mfofcut.fits'
dat = fits.open(name)
#mask = (match['redshift_1'] > .2)*(match['redshift_1'] < 1)
#mask = mask*(match['obs_2'] > 20)*(match['obs_1'] > 3e13)*(match['obs_2'] < 120)
#match = match[mask]

# %%
dat_open= dat[1].data

# %%
#dat_open

# %%
richness = dat_open['cat1_richness']
redshift = dat_open['cat2_z']
M200c = dat_open['cat2_M200c']

# %%
table = Table()

# %%
table['richness'] = dat_open['cat1_richness']
table['M200c'] = dat_open['cat2_M200c']
table['redshift'] = dat_open['cat1_ztrue_cg']

# %%
plt.figure(figsize=(7,5))
plt.tick_params(axis='both', which = 'major', labelsize= 14)
plt.grid(True, which="both")
plt.scatter(table['richness'], table['M200c'], c=table['redshift'], s=7, cmap='hsv')
plt.colorbar().set_label(label=r'redshift',size=20,)
plt.yscale('log')
plt.xscale('log')
plt.ylabel(r'DC2 $M_{\rm 200c}$', fontsize=20)
plt.xlabel('redMaPPer richness', fontsize=20)
radius = np.linspace(4, 20, 100)
plt.fill_between(radius, 0*radius + 1e16, alpha = .2, color = 'skyblue')# + 1e16)
#plt.savefig('DC2_mass_redmapper_richness.png', bbox_inches='tight', dpi=300)

# %%
table = table[(table['M200c'] > 1e13)*(table['richness'] > 20)*(table['redshift'] < .8)*(table['redshift'] > .2)]

# %%
mr = mass_richness.WL_Mass_Richness()
mr.set_pivot_values(analysis.z0, analysis.richness0)

# %%
def gaussian(x,x0,sigma):
    return np.exp(-(x - x0)**2/(2*sigma**2))/np.sqrt(2*np.pi*sigma**2)

# %%
def lnLikelihood(p):
    log10m0, G, F, sigma_int = p
 
    if sigma_int < 0: return -np.inf
    if log10m0 < 0: return -np.inf
    sigma_int_correct = np.sqrt(sigma_int**2 + F**2/table['richness'])
    #for s in sigma_int_correct:
    #    if s < 0: return -np.inf
    mu_lnm = mr.lnM(table['richness'], table['redshift'], [log10m0, G, F]) - sigma_int_correct**2/2
    #pM = np.exp(-.5*(np.log(table['M200c'])-mu_lnm)**2/(sigma_int_correct**2))/(sigma_int_correct*table['M200c'])
    pM = mr.gaussian(np.log(table['M200c']),mu_lnm, sigma_int_correct)/table['M200c']
    return np.sum(np.log(pM))

# %%
lnLikelihood([14,1,1, .1])
# Out:
# -59285.42668385161

# %%
ncpu = multiprocessing.cpu_count()
print('You have {0:1d} CPUs'.format(ncpu))
pool = multiprocessing.Pool(processes=ncpu)
# Out:
# You have 16 CPUs

# %%
nwalker=50
pos=.001*np.random.randn(nwalker,4) + np.array(np.array([14.15, -.4, .7, .4]))
sampler = emcee.EnsembleSampler(nwalker, 4, lnLikelihood, )#pool=pool)
sampler.run_mcmc(pos, 300, progress=True);
flat_samples1 = sampler.get_chain(discard=10, thin=3, flat=True)
# Out:
# 100%|██████████| 300/300 [00:16<00:00, 18.22it/s]

# %%
plt.plot(flat_samples1[:,-1])

# %%
log10m0, G, F, s = np.mean(flat_samples1[4000:], axis=0)

# %%
log10m0, G, F
# Out:
# (14.143400937625936, -0.2928247304142298, 0.8155885265688505)

# %%
np.save('fiducial.txt', np.array([log10m0, G, F, s]))
np.save('fiducial_sample.txt', flat_samples1[4000:])

# %%
table_cut = table[(table['richness'] > 30)*(table['richness'] < 40)*(table['redshift'] > .2)*(table['redshift'] < .4)]

# %%
import scipy
logm = np.linspace(30, 35, 200)
lambda_mean = np.mean(table_cut['richness'])
redshift_mean = np.mean(table_cut['redshift'])
sigma_int_correct = np.sqrt(s**2 + F**2/lambda_mean)
y = np.exp(-.5*(logm -  (mr.lnM(lambda_mean, redshift_mean, [log10m0, G, F])- sigma_int_correct**2/2))**2/(sigma_int_correct**2))
plt.hist(np.log(table_cut['M200c']), density = True, bins=10)
plt.plot(logm, y/scipy.integrate.simps( y, logm), 'k')
